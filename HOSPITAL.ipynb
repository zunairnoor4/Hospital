# %%
def main():
        import IPython.display
        #print('\033[1;30;42m {0:->62}{1:->41}'.format('  ABC HOSPITAL   ','-',))
        print('\033[1;30m {0:>34}{1:*>40} '.format(' ','*'))
        print('\033[5;35m {0:>62}'.format('  ABC HOSPITAL   '))
        print('\033[1;30m {0:>34}{1:*>40}'.format(' ','*'))
        print('')
        print('\033[1;36;47m {0:>78}{1:>31}'.format('  (choose any of the number for the process)   ','-',))
        print('')

        cardiologist = ['NAME : Dr.Mansoor Ahmed------TIME: Wed to Sat 5pm to 8pm-----FEES: Rs. 1500',
                        'NAME: Dr. Zia Yaqoob------TIME: Mon to Sat 7pm to 9pm-----FEES: Rs.1800']
        general_physician = ['NAME : Dr.Najia Ashraf------TIME: Mon to Thur & sat 1.30pm to 2.30pm----FEES: Rs 1000',
                             'NAME: prof. Azam Samdani------TIME: Mon to Thur 12pm to 2pm-----FEES: Rs.1200 ']
        gyneacologist = ['NAME: Dr. Irum Asghar------TIME: Mon to Fri 10am to 12pm-----FEES: Rs. 1800',
                         'NAME: Dr.Nabila saifi------TIME: Mon to Sat 10am to 1pm-----FEES: Rs. 1800']
        ophthalmologist = ['NAME: Dr. Imran Javed------TIME: Mon to Thur 2pm to 5pm-----FEES: Rs1200',
                           'NAME: Dr.Sami ur Rehman------TIME: Mon to Thur 4pm to 7pm-----FEES:Rs: 1500']
        neuro_surgeon = ['NAME: Dr. Asim Rehmani------TIME: Mon to Sat 5pm to 9pm-----FEES:Rs 2000',
                         'NAME: Dr.Junaid ashraf------TIME: Mon to Thur 4pm to 6 pm-----FEES:Rs 2500']
        Dr=['1-)Dr.Mansoor Ahmed','2-)Dr.Zia Yaqoob','3-)Dr.Najia Ashraf','4-)prof.Azam Samdani',
            '5-)Dr.Irum Asghar','6-)Dr.Nabila saifi','7-)Dr.Imran Javed','8-)Dr.Sami ur Rehman',
            '9-)Dr.Asim Rehmani','10-)Dr.Junaid ashraf']
        laboratory=['1-)ABG (Arterial blood gases)','2-)AIDS (Acquired immunodeficiency syndrome)',
                    '3-)BUN (Blood urea nitrogen)','4-)CBC (Complete blood count)','5-)CNS (Central nervous system)',
                    '6-)COPD (Chronic obstructive pulmonary disease)','7-)HAV (Hepatitis A virus)','8-)HBV (Hepatitis B virus)',
                    '9-)HCV (Hepatitis C virus)','10-)TSH (Thyroid stimulating hormone)']
        
        lst = ['1-)if patient visit before and have an appointment', '2-)make a new file for new patient',
               '3-)if patient want to check his record', '4-)Doctors we have right now',
               '5-)if you want to check doctor record', "6-)if you want to check overall record",
               "7-)information of doctor's OPD ","8-)Laboratory infotmation"]

        for r in lst:
            print('\033[1;2;43m', r,'\n')
        n = input('choose a number : ')
        print('')
        doctor = {
            'cardiologist': 'NAME: Dr.Mansoor Ahmed  TIME: Wed to Sat 5pm to 8pm  SPECIALIST : Cardiologist  Fees : Rs 1500 ',
            'general_physician': 'NAME : Dr.Najia Ashraf   TIME: Mon to Thur & sat 1.30pm to 2.30pm   SPECIALIST: General Physician  Fees : Rs 1000 ',
            'gyneacologist': 'NAME: Dr. Irum Asghar   TIME: Mon to Fri 10am to 12pm   SPECIALIST : Gyneacologist   Fees : Rs 1800',
            'ophthalmologist': 'NAME: Dr. Imran Javed    TIME: Mon to Thur 2pm to 5pm   SPECIALIST : Ophthalmologist   Fees :Rs 1200 ',
            'neuro_surgeon': 'NAME: Dr. Asim Rehmani    TIME: Mon to Sat 5pm to 9pm   SPECIALIST : Nuero Surgeon  Fees :Rs 2000'}
        doctors = {
            'cardiologist': 'NAME: Dr. Zia Yaqoob   TIME: Mon to Sat 7pm to 9pm   SPECIALIST: Cardiologist  Fees: Rs 1800',
            'general_physician': 'NAME: prof. Azam Samdani    TIME: Mon to Thur 12pm to 2pm   SPECIALIST: General Physician   Fees: Rs 1200',
            'gyneacologist': 'NAME: Dr.Nabila saifi    TIME: Mon to Sat 10am to 1pm    SPECIALIST: Gyneacologist   Fees: Rs 1800',
            'ophthalmologist': 'NAME: Dr.Sami ur Rehman    TIME: Mon to Thur 4pm to 7pm   SPECIALIST: Ophthalmologist  Fees: Rs 1500',
            'neuro_surgeon': 'NAME: Dr.Junaid ashraf    TIME: Mon to Thur 4pm to 6 pm   SPECIALIST: Nuero Surgeon   Fees:Rs 2500'}
        #dict2 = {}
        if n == '1':
            IPython.display.clear_output()
            print('\033[5;30;46m ask for a file number from a patient ')
            print('')
            print('')
            file1=open('patient.txt','r')
            x=file1.readlines()
            file1.close()
            print('\033[3;37;40m HINT : your Phone no is your file number')
            print('')
            print('\033[3;37;40m HINT : File Numbers are 03322465343 or 03317683466 or 03152101119 or 03345678999')
            print('')
            no= input('\033[1;34;49m enter file number ')
            print('')
            for i in x:
                i=i.split()
                if i[0] == no:
                    IPython.display.clear_output()
                    print('\033[1;33;40m','RECORD OF FILE NO :',i[0])
                    print('')
                    print('\033[1;36;47m', i)
                    
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a=='yes':
                IPython.display.clear_output()
                main()
            
            exit()
        elif n == '2':
            print('\033[5;30;46m making a new file')
            NAME = input('\033[1;30;46m enter patient name :')
            print('')
            AGE = input('\033[1;30;46m enter Age : ')
            print('')
            print('\033[3;37;40m Hint : you come first time so enter "NO" \n')
            print('')
            LAST_VISIT = input('\033[1;30;46m enter last visit : ')
            print('')
            VISITING_DATE=input('\033[1;30;46m enter date of appointment : ')
            print('')
            for i in cardiologist:
                print('\033[2;30;43m Cardiologist: \n',i)
            for i in general_physician:
                print('\033[1;30;43m General Physician: \n',i)
            for i in gyneacologist:
                print('\033[1;30;43m Gyneacologist: \n',i)
            for i in ophthalmologist:
                print('\033[1;30;43m Ophthalmologist: \n',i)
            for i in neuro_surgeon:
                print('\033[1;30;43m Neuro Surgeon: \n',i)
            print('')
            DOCTOR = input('\033[1;30;46m which doctor you want to visit :')
            PHONE_no = str(input('\033[1;30;46m enter phone number : '))   # str CONVERTS INTEGER NUMBERS TO THE STRING
            print('')
            print('\033[5;30;46m your Phone no. is your FILE NUMBER')
            print('')
            DEPOSITE_FEES=str(input('\033[1;30;46m enter amount of fees : '))
            key = PHONE_no
            data= key+ " "+'NAME:'+NAME+' '+'AGE:'+AGE+' '+'LAST_VISIT:'+LAST_VISIT+' '+'VISITING_DATE:'+VISITING_DATE+" "+'DOCTOR:'+DOCTOR+' '+'PHONE NUMBER:'+PHONE_no+' '+'DEPOSITE FEES:'+DEPOSITE_FEES
            print('')
            print('\033[3;37;40m Paid fees is Rs.',DEPOSITE_FEES)
            print('')
            IPython.display.clear_output()
            print('\033[3;37;40m your FILE NUMBER is : ', key)
            pa1=open('patient.txt','a')
            print('')
            print('\033[1;36;47m your whole record is :',data)
            d2=str(data)            
            pa1.write(d2)
            pa1.write('\n')
            pa1.close()
            print(" ")
            print('')
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
        elif n == '3':
            IPython.display.clear_output()
            print('\033[5;30;46m ask for a file number from a patient ')    
            print('')
            file3=open('patient.txt','r')
            y=file3.readlines()
            file3.close()
            print('\033[3;37;40m HINT : File Numbers are 03322465343 or 03317683466 or 03152101119 or 03345678999')
            print('')
            
            no = input('\033[1;34;49m enter file number : ')
            print('')
            for j in y:
                j=j.split()
                if j[0] == no:
                    IPython.display.clear_output()
                    print('\033[5;30;46m your previous record is :')
                    print('')
                    print('\033[1;36;47m', j)
            print('')
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
        elif n == '4':
            IPython.display.clear_output()
            print('\033[5;30;46m Doctors we have in our Hospital')
            print('')
            print('\033[1;30;42m {0:->42}{1:->20}'.format('   CARDIOLOGIST   ','-',))
            print('')
            for i in cardiologist:
                print('\033[1;2;43m', i)
            print('')
            print('\033[1;30;42m  {0:->42}{1:->20}'.format('   GENERAL PHYSICIAN   ','-',))
            print('')
            for i in general_physician:
                print('\033[1;2;43m', i)
            print('')
            print('\033[1;30;42m  {0:->42}{1:->20}'.format('   GYNEACHOLOGIST   ','-',))
            print('')
            for i in gyneacologist:
                print('\033[1;2;43m', i)
            print('')
            print('\033[1;30;42m  {0:->42}{1:->20}'.format('   OPHTHALMOLOGIST   ','-',))
            print('')
            for i in ophthalmologist:
                print('\033[1;2;43m', i)
            print('')
            print('\033[1;30;42m  {0:->42}{1:->20}'.format('   NEURO SURGEON   ','-',))
            print('')
            for i in neuro_surgeon:
                print('\033[1;2;43m', i)
            print('')
            
            a = input('enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
        elif n == '5':
            IPython.display.clear_output()
            print('\033[1;30;42m  {0:->52}{1:->30}'.format('   INFORMATION OF DOCTOR   ','-',))
            print('')
            dept=['cardiologist','general_physician','gyneacologist','ophthalmologist','neuro_surgeon']
            for r in dept:
                print('\033[1;2;43m', r)
            print('')
            print('\033[3;37;40m HINT : Enter department name from given above ')
            key = input('\033[1;34;49m enter type for particular doctor of department : ')
            print('')
            if key not in dept:
                print('\033[1;31;47m {0:*>30}{1:*>30}'.format  ("ERROR" ,"*",))
                print('')
                print('\033[4;30,49m PLEASE ENTER VALID DEPARTMENT!')
            else:
                print('\033[1;30;45m', doctor[key])
                print('\033[1;30;45m', doctors[key])
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
        elif n == '6':
            IPython.display.clear_output()
            print('\033[1;30;42m {0:->62}{1:->40}'.format('   PATIENTS RECORDS ARE   ','-',))
            print('')
            
            f6=open('patient.txt','r')
            l=f6.read()
            f6.close()
            print('\033[1;38;46m records',l)
            
            print('')
            print('\033[1;30;42m {0:->62}{1:->40}'.format('   DOCTORS RECORDS ARE   ','-',))
            print('')
            print('\033[1;38;46m doctor', doctor)
            print('\033[1;38;46m doctor', doctors)
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
        elif n=='7':
            IPython.display.clear_output()
            print('\033[1;36;47m {0:>40}{1:>27}'.format ('Doctors we have',' '))
            print('')
            for i in Dr:
                print('\033[1;2;43m',i)
            print('')
            print('\033[3;37;40m HINT : Enter between 1 to 10 ')
            print('')
            a=input('\033[1;34;49m choose any of the following number to get information of following doctor')
            print('')
            if a=='1':
                print('\033[1;30;43m Dr.Mansoor Ahmed','\n','Department of Cardiologist','\n','Ground Floor','\n','Consultant Clinic no.1')
            elif a=='2':
                 print('\033[1;30;43m Dr. Zia Yaqoob','\n','Department of Cardiologist','\n','Ground Floor','\n','Consultant Clinic no.2')
            elif a=='3':
                print('\033[1;30;43m Dr.Najia Ashraf','\n','Department of General Physician','\n','First Floor','\n','Consultant Clinic no.3')
            elif a=='4':
                print('\033[1;30;43m prof. Azam Samdani','\n','Department of General Physician','\n','First Floor','\n','Consultant Clinic no.4')
            elif a=='5':
                print('\033[1;30;43m Dr. Irum Asghar','\n','Department of Gyneacologist','\n','Secend Floor','\n','Consultant Clinic no.5')
            elif a=='6':
                print('\033[1;30;43m Dr.Nabila saifi','\n','Department of Gyneacologist','\n','Secend Floor','\n','Consultant Clinic no.6')
            elif a=='7':
                print('\033[1;30;43m Dr.Imran Javed','\n','Department of Ophthalmologist','\n','Secend Floor','\n','Consultant Clinic no.7')
            elif a=='8':
                print('\033[1;30;43m Dr.Sami ur Rehman','\n','Department of Ophthalmologist','\n','Secend Floor','\n','Consultant Clinic no.8')
            elif a=='9':
                print('\033[1;30;43m Dr. Asim Rehmani','\n','Department of Ophthalmologist','\n','Third Floor','\n','Consultant Clinic no.9')
            elif a=='10':
                print('\033[1;30;43m Dr.Junaid ashraf','\n','Department of Ophthalmologist','\n','Third Floor','\n','Consultant Clinic no.10')
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
        elif n=='8':
            IPython.display.clear_output()
            print('\033[1;36;47m {0:>30}{0:<30}'.format ('LABORATORY INFORMATION'))
            print('')
            print('\033[5;30;46m WE HAVE 24/7 SERVICE OF LABORATORY')
            print('')
            for i in laboratory:
                print(i)
            print('')
            print('\033[3;37;40m HINT : CHOOSE ANY OF GIVEN ABOVE FOR THE PROCESS')
            print('')
            
            a=input('\033[1;30;46m Choose any of given above :')
           
            print('')
            if a=='1':
                print('\033[1;30;43m ABG (Arterial blood gases)--------Rs 1200','\n','Reports Can Be Collected After 5 hours')
            elif a=='2':
                print('\033[1;30;43m AIDS (Acquired immunodeficiency syndrome)--------Rs 1500','\n','Reports Can Be Collected After 3 hours')
            elif a=='3':
                print('\033[1;30;43m BUN (Blood urea nitrogen)--------Rs 1800','\n','Reports Can Be Collected After 7 hours')
            elif a=='4':
                print('\033[1;30;43m CBC (Complete blood count)--------Rs 900','\n','Reports Can Be Collected After 3 hours')
            elif a=='5':
                print('\033[1;30;43m CNS (Central nervous system)--------Rs 1100','\n','Reports Can Be Collected After 1 day')
            elif a=='6':
                print('\033[1;30;43m COPD (Chronic obstructive pulmonary disease)--------Rs 1800','\n','Reports Can Be Collected After 1 day')
            elif a=='7':
                print('\033[1;30;43m HAV (Hepatitis A virus)--------Rs 1200','\n','Reports Can Be Collected After 5 hours')
            elif a=='8':
                print('\033[1;30;43m HBV (Hepatitis B virus)--------Rs 1200','\n','Reports Can Be Collected After 5 hours')
            elif a=='9':
                print('\033[1;30;43m HCV (Hepatitis C virus)--------Rs 1200','\n','Reports Can Be Collected After 5 hours')
            elif a=='10':
                print('\033[1;30;43m TSH (Thyroid stimulating hormone)--------Rs 1350','\n','Reports Can Be Collected After  1 day')
            print('')
            a = input('\033[1;34;49m enter yes or no to go on start page : ')
            if a == 'yes':
                IPython.display.clear_output()
                main()
            exit()
main()
# Out:
#                                    ****************************************
#                                                 ABC HOSPITAL
#                                    ****************************************
#
#                                   (choose any of the number for the process)                                 -
#
#  1-)if patient visit before and have an appointment
#
#  2-)make a new file for new patient
#
#  3-)if patient want to check his record
#
#  4-)Doctors we have right now
#
#  5-)if you want to check doctor record
#
#  6-)if you want to check overall record
#
#  7-)information of doctor's OPD
#
#  8-)Laboratory infotmation
